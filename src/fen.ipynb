# %%
import numpy as np
import pandas as pd

# %%
mimic_data = pd.read_csv("mimic_data.csv")
eicu_data = pd.read_csv("eicu_data.csv")

# %%
eicu_data['label'].value_counts()

# %%
mimic_data['label'].value_counts()

# %%
X = mimic_data.drop(columns=['label'])
Y = mimic_data['label']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.3,
    stratify=Y,
    random_state=42
)

# %%
eicu_X = eicu_data.drop(columns=['label'])
eicu_Y = eicu_data['label']
X_val, y_val = eicu_X, eicu_Y

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
