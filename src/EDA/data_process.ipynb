# %%
import pandas as pd
import numpy as np
import os

mimic_data = pd.read_csv("../../data/mmicrodeficiency/mimic_data.csv")
eicu_data = pd.read_csv("../../data/mmicrodeficiency/eicu_data.csv")

# %%
# 1. 创建保存结果的目录
output_dir = '../../res/mimic_eda'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 2. 定义保存结果的文件名
output_file = os.path.join(output_dir, 'mimic_eda_results.txt')

# 3. EDA 分析 (并将所有结果写入同一个文件)
with open(output_file, 'w') as f:

    # 3.1 总体信息
    f.write("---------- 总体信息 ----------\n\n")
    f.write(f"数据形状：{mimic_data.shape}\n")
    f.write(f"列名：{', '.join(mimic_data.columns)}\n")
    f.write("\n数据类型：\n")
    f.write(str(mimic_data.dtypes) + "\n")
    f.write("\n前5行数据：\n")
    f.write(str(mimic_data.head()) + "\n")

    # 3.2 缺失值分析
    f.write("\n---------- 缺失值分析 ----------\n\n")
    f.write("每个特征的缺失数量：\n")
    f.write(str(mimic_data.isnull().sum()) + "\n")
    f.write("\n每个特征的缺失比例：\n")
    f.write(str(mimic_data.isnull().mean()) + "\n")

    # 可视化缺失值（用字符图代替）
    f.write("\n缺失值可视化 (字符图):\n")
    missing_matrix = mimic_data.isnull().astype(int).to_string()
    f.write(missing_matrix + "\n")
    f.write("  (1 表示缺失, 0 表示非缺失)\n")

    # 3.3 描述性统计
    f.write("\n---------- 描述性统计 ----------\n\n")
    f.write("数值型特征：\n")
    f.write(str(mimic_data.describe(include=[np.number])) + "\n")

    # 检查是否有类别型特征
    if any(mimic_data.dtypes == 'object'):
        f.write("\n类别型特征：\n")
        f.write(str(mimic_data.describe(include=['O'])) + "\n")  # 'O' for object
    else:
        f.write("\n没有类别型特征。\n")

    # 3.4 类别型特征的频数分布（同样需要检查）
    f.write("\n---------- 类别型特征频数分布 ----------\n\n")
    if any(mimic_data.dtypes == 'object'):
        for col in mimic_data.select_dtypes(include=['O']).columns:
            f.write(f"特征 '{col}' 的频数分布：\n")
            f.write(str(mimic_data[col].value_counts()) + "\n")
            f.write("\n")
    else:
        f.write("没有类别型特征。\n")

    # 3.5 数值型特征的分布 (用分位数和直方图的文本描述代替)
    f.write("\n---------- 数值型特征分布 ----------\n\n")
    for col in mimic_data.select_dtypes(include=[np.number]).columns:
        f.write(f"特征 '{col}' 的分布：\n")
        # 分位数
        quantiles = mimic_data[col].quantile([0, 0.25, 0.5, 0.75, 1]).to_string()
        f.write(f"分位数：\n{quantiles}\n")

        # 文本直方图 (用numpy生成数据)
        hist, bin_edges = np.histogram(mimic_data[col].dropna(), bins=10)
        f.write("\n直方图 (文本形式):\n")
        for i in range(len(hist)):
            f.write(f"[{bin_edges[i]:.2f}, {bin_edges[i+1]:.2f}): {'*' * hist[i]} ({hist[i]})\n")
        f.write("\n")

    # 3.6 (可选) 相关性分析 (数值型特征)
    f.write("\n---------- 相关性分析 (数值型特征) ----------\n\n")
    correlation_matrix = mimic_data.corr()
    f.write(str(correlation_matrix) + "\n")

     # 文本热图 (使用符号表示相关性强度)
    f.write("\n相关性热图 (文本形式):\n")
    for i in range(len(correlation_matrix)):
        row_str = ""
        for j in range(len(correlation_matrix)):
            corr_val = correlation_matrix.iloc[i, j]
            if abs(corr_val) >= 0.8:
                symbol = "++" if corr_val > 0 else "--"
            elif abs(corr_val) >= 0.5:
                symbol = "+" if corr_val > 0 else "-"
            else:
                symbol = "  "
            row_str += f"{symbol} "
        f.write(row_str + '\n')
print("EDA 结果已保存至 '../../res/mimic_eda/mimic_eda_results.txt' 文件中。")
# Out:
# EDA 结果已保存至 '../../res/mimic_eda/mimic_eda_results.txt' 文件中。

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os


try:
    import missingno as msno
    HAS_MISSINGNO = True
except ImportError:
    HAS_MISSINGNO = False
    print("Warning: missingno library is not installed. Missing value visualization will be skipped.")

plt.rcParams['font.sans-serif'] = ['SimHei'] 
plt.rcParams['axes.unicode_minus'] = False

def perform_eda(data, label_col='label', output_dir='eda_results'):
    """
    对DataFrame进行探索性数据分析 (EDA) 并将结果保存到指定目录，
    包括整体数据、每个Label类别以及 "谵妄 vs. 非谵妄" 分组的分析。

    参数:
    data (pd.DataFrame): 输入的DataFrame，包含标签列。
    label_col (str): 标签列的名称，默认为 'label'。
    output_dir (str): 保存EDA结果的目录，默认为 'eda_results'。
    """

    # 确保输出目录存在
    os.makedirs(output_dir, exist_ok=True)
    insights_dir = os.path.join(output_dir, 'insights') # 创建 insights 总目录
    os.makedirs(insights_dir, exist_ok=True)

    summary_insights_file = os.path.join(insights_dir, 'eda_insights_summary.txt') # 总的文本逻辑文件

    print(f"开始 EDA 分析，结果将保存到目录: {output_dir}")

    # 初始化总的文本逻辑内容
    summary_content = f"EDA 总逻辑总结\n===================\n\n"

    # 1. 数据概览 (Data Overview) - 整体数据
    print("\n1. 数据概览 (Data Overview) - 整体数据...")
    overall_dir = os.path.join(output_dir, 'overall') # 整体数据结果目录
    os.makedirs(overall_dir, exist_ok=True)
    data_overview_file = os.path.join(overall_dir, 'data_overview.txt')
    with open(data_overview_file, 'w', encoding='utf-8') as f: # 指定 utf-8 编码
        f.write("数据形状 (Shape):\n")
        f.write(str(data.shape) + "\n\n")
        f.write("数据类型 (Data Types):\n")
        f.write(str(data.dtypes) + "\n\n")
        f.write("缺失值统计 (Missing Values):\n")
        f.write(str(data.isnull().sum()) + "\n\n")
        f.write("前5行数据 (Head):\n")
        f.write(str(data.head()) + "\n")
    print(f"  - 整体数据概览信息已保存到: {data_overview_file}")
    summary_content += f"1. 数据概览 (Data Overview) - 整体数据 (详细信息见 {data_overview_file}):\n"
    with open(data_overview_file, 'r', encoding='utf-8') as f:
        summary_content += f.read() + "\n\n"


    # 2. 描述性统计 (Descriptive Statistics) - 整体数据
    print("\n2. 描述性统计 (Descriptive Statistics) - 整体数据...")
    desc_stats = data.describe(include='all').T  # 转置方便查看
    desc_stats_file = os.path.join(overall_dir, 'descriptive_statistics.csv')
    desc_stats.to_csv(desc_stats_file, encoding='utf-8') # 指定 utf-8 编码
    print(f"  - 整体数据描述性统计信息已保存到: {desc_stats_file}")
    summary_content += f"2. 描述性统计 (Descriptive Statistics) - 整体数据 (详细信息见 {desc_stats_file}):\n"
    summary_content += f"  - (请查看 {desc_stats_file} 文件获取详细的描述性统计信息，例如均值、中位数、标准差、分位数等)\n\n"


    # 3. 分 Label 类别进行单变量分析
    label_values = sorted(data[label_col].unique())
    for label_value in label_values:
        label_data = data[data[label_col] == label_value]
        label_dir = os.path.join(output_dir, f'label_{label_value}') # 每个 Label 的结果目录
        os.makedirs(label_dir, exist_ok=True)
        print(f"\n3. Label {label_value} 单变量分析...")
        summary_content += f"\n3. Label {label_value} 单变量分析:\n"

        numerical_features = label_data.select_dtypes(include=np.number).columns.tolist()
        categorical_features = label_data.select_dtypes(exclude=np.number).columns.tolist()

        # 数值特征单变量分析 - 分 Label
        print("  - 数值特征单变量分析...")
        for col in numerical_features:
            if col == label_col:
                continue
            plt.figure(figsize=(8, 6))
            hist_plot = plt.hist(label_data[col].dropna(), bins=30)
            plt.title(f'Label {label_value} - 数值特征分布 - {col}') # 标题包含 Label
            plt.xlabel(col)
            plt.ylabel('频率')
            hist_file = os.path.join(label_dir, f'hist_{col}.png') # 保存到 Label 目录
            plt.savefig(hist_file)
            plt.close()
            print(f"    - {col} 直方图已保存: {hist_file}")

            # 保存直方图逻辑到文本
            hist_insights_file = os.path.join(insights_dir, f'label_{label_value}_hist_insights_{col}.txt') # insights 文件名包含 Label
            with open(hist_insights_file, 'w', encoding='utf-8') as f_insights:
                f_insights.write(f"Label {label_value} - 数值特征 {col} 直方图分析:\n") # 文本内容包含 Label
                f_insights.write(f"  - 数据分布大致形状:  (请查看直方图 {hist_file} )\n")
                counts, bins = hist_plot[0], hist_plot[1]
                peak_bin_index = np.argmax(counts)
                peak_bin_center = (bins[peak_bin_index] + bins[peak_bin_index + 1]) / 2
                f_insights.write(f"  - 峰值大致位置 (众数): {peak_bin_center:.2f}\n")
                f_insights.write(f"  - 可能的分布类型: (需要人工判断).\n")
                # ... (更详细的描述性统计信息，与之前的代码相同) ...
                mean_val = label_data[col].mean()
                median_val = label_data[col].median()
                skewness = label_data[col].skew()
                f_insights.write(f"  - 均值 (Mean): {mean_val:.2f}\n")
                f_insights.write(f"  - 中位数 (Median): {median_val:.2f}\n")
                f_insights.write(f"  - 偏度 (Skewness): {skewness:.2f}\n")
                f_insights.write(f"  - 数据值大致范围: 从 {label_data[col].min():.2f} 到 {label_data[col].max():.2f}\n")
            print(f"    - {col} 直方图逻辑已保存: {hist_insights_file}")
            summary_content += f"  3.1. 数值特征单变量分析 - {col} (Label {label_value}, 详细逻辑见 {hist_insights_file}, 图表见 {hist_file}):\n"
            with open(hist_insights_file, 'r', encoding='utf-8') as f_insight_read:
                summary_content += f_insight_read.read()


            plt.figure(figsize=(8, 6))
            boxplot = sns.boxplot(y=label_data[col].dropna())
            plt.title(f'Label {label_value} - 数值特征箱线图 - {col}') # 标题包含 Label
            plt.ylabel(col)
            boxplot_file = os.path.join(label_dir, f'boxplot_{col}.png') # 保存到 Label 目录
            plt.savefig(boxplot_file)
            plt.close()
            print(f"    - {col} 箱线图已保存: {boxplot_file}")

            # 保存箱线图逻辑到文本
            boxplot_insights_file = os.path.join(insights_dir, f'label_{label_value}_boxplot_insights_{col}.txt') # insights 文件名包含 Label
            with open(boxplot_insights_file, 'w', encoding='utf-8') as f_insights:
                f_insights.write(f"Label {label_value} - 数值特征 {col} 箱线图分析:\n") # 文本内容包含 Label
                f_insights.write(f"  - 中位数 (Median): {label_data[col].median():.2f}\n")
                f_insights.write(f"  - 四分位数范围 (IQR): {label_data[col].quantile(0.75) - label_data[col].quantile(0.25):.2f}\n")
                f_insights.write(f"  - 异常值情况: (请查看箱线图 {boxplot_file} )\n")
                # ... (更详细的箱线图描述，与之前的代码相同) ...
                q1 = label_data[col].quantile(0.25)
                q3 = label_data[col].quantile(0.75)
                iqr = q3 - q1
                lower_whisker = label_data[col][label_data[col] >= (q1 - 1.5 * iqr)].min()
                upper_whisker = label_data[col][label_data[col] <= (q3 + 1.5 * iqr)].max()
                outliers = label_data[col][(label_data[col] < (q1 - 1.5 * iqr)) | (label_data[col] > (q3 + 1.5 * iqr))]
                f_insights.write(f"  - 下四分位数 (Q1): {q1:.2f}\n")
                f_insights.write(f"  - 上四分位数 (Q3): {q3:.2f}\n")
                f_insights.write(f"  - 下须 (Lower Whisker): {lower_whisker:.2f}\n")
                f_insights.write(f"  - 上须 (Upper Whisker): {upper_whisker:.2f}\n")
                f_insights.write(f"  - 异常值数量 (Outliers, 1.5*IQR rule): {len(outliers)}\n")
                f_insights.write(f"  - 数据分布的对称性/偏斜程度: (根据中位数和箱体位置、须的长度判断).\n")
            print(f"    - {col} 箱线图逻辑已保存: {boxplot_insights_file}")
            summary_content += f"  3.1. 数值特征单变量分析 - {col} (Label {label_value}, 详细逻辑见 {boxplot_insights_file}, 图表见 {boxplot_file}):\n"
            with open(boxplot_insights_file, 'r', encoding='utf-8') as f_insight_read:
                summary_content += f_insight_read.read()


        # 类别特征单变量分析 - 分 Label
        print("  - 类别特征单变量分析...")
        for col in categorical_features:
            if col == label_col:
                continue
            plt.figure(figsize=(8, 6))
            countplot = sns.countplot(x=col, data=label_data)
            plt.title(f'Label {label_value} - 类别特征分布 - {col}') # 标题包含 Label
            plt.xlabel(col)
            plt.ylabel('计数')
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            countplot_file = os.path.join(label_dir, f'countplot_{col}.png') # 保存到 Label 目录
            plt.savefig(countplot_file)
            plt.close()
            print(f"    - {col} 柱状图已保存: {countplot_file}")

            # 保存柱状图逻辑到文本
            countplot_insights_file = os.path.join(insights_dir, f'label_{label_value}_countplot_insights_{col}.txt') # insights 文件名包含 Label
            with open(countplot_insights_file, 'w', encoding='utf-8') as f_insights:
                f_insights.write(f"Label {label_value} - 类别特征 {col} 柱状图分析:\n") # 文本内容包含 Label
                category_counts = label_data[col].value_counts()
                f_insights.write("  - 各类别计数:\n")
                f_insights.write(str(category_counts) + "\n")
                # ... (更详细的类别特征描述，与之前的代码相同) ...
                total_count = len(label_data[col])
                category_percentages = category_counts / total_count * 100
                f_insights.write("  - 各类别百分比:\n")
                f_insights.write(str(category_percentages.round(2)) + "%\n")
                f_insights.write(f"  - 类别分布是否均衡: (根据各类别计数/比例判断).\n")
                f_insights.write(f"  - 常见类别: {category_counts.index[0]} (计数: {category_counts.iloc[0]})\n")
                rare_categories = category_counts[category_counts < total_count * 0.01]
                if not rare_categories.empty:
                    f_insights.write(f"  - 稀有类别 (少于1%): {', '.join(rare_categories.index.tolist())}\n")
                else:
                    f_insights.write(f"  - 无明显稀有类别 (少于1%).\n")
            print(f"    - {col} 柱状图逻辑已保存: {countplot_insights_file}")
            summary_content += f"  3.2. 类别特征单变量分析 - {col} (Label {label_value}, 详细逻辑见 {countplot_insights_file}, 图表见 {countplot_file}):\n"
            with open(countplot_insights_file, 'r', encoding='utf-8') as f_insight_read:
                summary_content += f_insight_read.read()


    # 4. 创建 "谵妄 vs. 非谵妄" 分组
    data['label_group'] = data[label_col].apply(lambda x: 'Delirium' if x in [0, 1, 2] else 'No Delirium')
    group_label_col = 'label_group' # 新的分组标签列名
    group_dir = os.path.join(output_dir, 'delirium_vs_no_delirium') # 分组数据结果目录
    os.makedirs(group_dir, exist_ok=True)
    print(f"\n4. \"谵妄 vs. 非谵妄\" 分组 EDA 分析...")
    summary_content += f"\n4. \"谵妄 vs. 非谵妄\" 分组 EDA 分析:\n"


    # 5. 分组数据的单变量分析
    print("  - 分组数据单变量分析...")
    group_numerical_features = data.select_dtypes(include=np.number).columns.tolist()
    group_categorical_features = data.select_dtypes(exclude=np.number).columns.tolist()

    # 数值特征单变量分析 - 分组数据
    print("    - 数值特征单变量分析...")
    for col in group_numerical_features:
        if col in [label_col, group_label_col]: # 避免对原始标签和分组标签进行数值特征的单变量分析
            continue
        plt.figure(figsize=(8, 6))
        hist_plot = plt.hist(data[col].dropna(), bins=30)
        plt.title(f'分组 - 数值特征分布 - {col}') # 标题包含 "分组"
        plt.xlabel(col)
        plt.ylabel('频率')
        hist_file = os.path.join(group_dir, f'hist_{col}.png') # 保存到分组目录
        plt.savefig(hist_file)
        plt.close()
        print(f"      - {col} 直方图已保存: {hist_file}")

        # 保存直方图逻辑到文本
        hist_insights_file = os.path.join(insights_dir, f'group_hist_insights_{col}.txt') # insights 文件名包含 "group"
        with open(hist_insights_file, 'w', encoding='utf-8') as f_insights:
            f_insights.write(f"分组 - 数值特征 {col} 直方图分析:\n") # 文本内容包含 "分组"
            f_insights.write(f"  - 数据分布大致形状:  (请查看直方图 {hist_file} )\n")
            # ... (描述性统计信息，与之前的代码相同) ...
            mean_val = data[col].mean()
            median_val = data[col].median()
            skewness = data[col].skew()
            f_insights.write(f"  - 均值 (Mean): {mean_val:.2f}\n")
            f_insights.write(f"  - 中位数 (Median): {median_val:.2f}\n")
            f_insights.write(f"  - 偏度 (Skewness): {skewness:.2f}\n")
            f_insights.write(f"  - 数据值大致范围: 从 {data[col].min():.2f} 到 {data[col].max():.2f}\n")
        print(f"      - {col} 直方图逻辑已保存: {hist_insights_file}")
        summary_content += f"  4.1. 分组数据单变量分析 - 数值特征 {col} (详细逻辑见 {hist_insights_file}, 图表见 {hist_file}):\n"
        with open(hist_insights_file, 'r', encoding='utf-8') as f_insight_read:
            summary_content += f_insight_read.read()


        plt.figure(figsize=(8, 6))
        boxplot = sns.boxplot(y=data[col].dropna())
        plt.title(f'分组 - 数值特征箱线图 - {col}') # 标题包含 "分组"
        plt.ylabel(col)
        boxplot_file = os.path.join(group_dir, f'boxplot_{col}.png') # 保存到分组目录
        plt.savefig(boxplot_file)
        plt.close()
        print(f"      - {col} 箱线图已保存: {boxplot_file}")

        # 保存箱线图逻辑到文本
        boxplot_insights_file = os.path.join(insights_dir, f'group_boxplot_insights_{col}.txt') # insights 文件名包含 "group"
        with open(boxplot_insights_file, 'w', encoding='utf-8') as f_insights:
            f_insights.write(f"分组 - 数值特征 {col} 箱线图分析:\n") # 文本内容包含 "分组"
            f_insights.write(f"  - 中位数 (Median): {data[col].median():.2f}\n")
            f_insights.write(f"  - 四分位数范围 (IQR): {data[col].quantile(0.75) - data[col].quantile(0.25):.2f}\n")
            f_insights.write(f"  - 异常值情况: (请查看箱线图 {boxplot_file} )\n")
            # ... (更详细的箱线图描述，与之前的代码相同) ...
            q1 = data[col].quantile(0.25)
            q3 = data[col].quantile(0.75)
            iqr = q3 - q1
            lower_whisker = data[col][data[col] >= (q1 - 1.5 * iqr)].min()
            upper_whisker = data[col][data[col] <= (q3 + 1.5 * iqr)].max()
            outliers = data[col][(data[col] < (q1 - 1.5 * iqr)) | (data[col] > (q3 + 1.5 * iqr))]
            f_insights.write(f"  - 下四分位数 (Q1): {q1:.2f}\n")
            f_insights.write(f"  - 上四分位数 (Q3): {q3:.2f}\n")
            f_insights.write(f"  - 下须 (Lower Whisker): {lower_whisker:.2f}\n")
            f_insights.write(f"  - 上须 (Upper Whisker): {upper_whisker:.2f}\n")
            f_insights.write(f"  - 异常值数量 (Outliers, 1.5*IQR rule): {len(outliers)}\n")
            f_insights.write(f"  - 数据分布的对称性/偏斜程度: (根据中位数和箱体位置、须的长度判断).\n")
        print(f"      - {col} 箱线图逻辑已保存: {boxplot_file}")
        summary_content += f"  4.1. 分组数据单变量分析 - 数值特征 {col} (详细逻辑见 {boxplot_insights_file}, 图表见 {boxplot_file}):\n"
        with open(boxplot_insights_file, 'r', encoding='utf-8') as f_insight_read:
            summary_content += f_insight_read.read()


        # 类别特征单变量分析 - 分组数据
        print("    - 类别特征单变量分析...")
        for col in group_categorical_features:
            if col in [label_col, group_label_col]: # 避免对原始标签和分组标签进行类别特征的单变量分析
                continue
            plt.figure(figsize=(8, 6))
            countplot = sns.countplot(x=col, data=data)
            plt.title(f'分组 - 类别特征分布 - {col}') # 标题包含 "分组"
            plt.xlabel(col)
            plt.ylabel('计数')
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            countplot_file = os.path.join(group_dir, f'countplot_{col}.png') # 保存到分组目录
            plt.savefig(countplot_file)
            plt.close()
            print(f"      - {col} 柱状图已保存: {countplot_file}")

            # 保存柱状图逻辑到文本
            countplot_insights_file = os.path.join(insights_dir, f'group_countplot_insights_{col}.txt') # insights 文件名包含 "group"
            with open(countplot_insights_file, 'w', encoding='utf-8') as f_insights:
                f_insights.write(f"分组 - 类别特征 {col} 柱状图分析:\n") # 文本内容包含 "分组"
                category_counts = data[col].value_counts()
                f_insights.write("  - 各类别计数:\n")
                f_insights.write(str(category_counts) + "\n")
                # ... (更详细的类别特征描述，与之前的代码相同) ...
                total_count = len(data[col])
                category_percentages = category_counts / total_count * 100
                f_insights.write("  - 各类别百分比:\n")
                f_insights.write(str(category_percentages.round(2)) + "%\n")
                f_insights.write(f"  - 类别分布是否均衡: (根据各类别计数/比例判断).\n")
                f_insights.write(f"  - 常见类别: {category_counts.index[0]} (计数: {category_counts.iloc[0]})\n")
                rare_categories = category_counts[category_counts < total_count * 0.01]
                if not rare_categories.empty:
                    f_insights.write(f"  - 稀有类别 (少于1%): {', '.join(rare_categories.index.tolist())}\n")
                else:
                    f_insights.write(f"  - 无明显稀有类别 (少于1%).\n")
            print(f"      - {col} 柱状图逻辑已保存: {countplot_insights_file}")
            summary_content += f"  4.2. 分组数据单变量分析 - 类别特征 {col} (详细逻辑见 {countplot_insights_file}, 图表见 {countplot_file}):\n"
            with open(countplot_insights_file, 'r', encoding='utf-8') as f_insight_read:
                summary_content += f_insight_read.read()


    # 6. 分组数据的双变量分析 (特征 vs. label_group)
    print("  - 分组数据的双变量分析 (vs. label_group)...")

    # 数值特征 vs. label_group
    print("    - 数值特征 vs. label_group...")
    for col in group_numerical_features:
        if col in [label_col, group_label_col]:
            continue
        plt.figure(figsize=(8, 6))
        boxplot_vs_group = sns.boxplot(data=data, x=group_label_col, y=col) # x 轴为分组标签
        plt.title(f'分组 - 数值特征 vs. 分组标签 - {col} vs. {group_label_col}') # 标题包含 "分组"
        plt.xlabel(group_label_col) # x 轴标签为分组标签列名
        plt.ylabel(col)
        boxplot_vs_group_file = os.path.join(group_dir, f'boxplot_{col}_vs_group_label.png') # 保存到分组目录
        plt.savefig(boxplot_vs_group_file)
        plt.close()
        print(f"      - {col} vs. {group_label_col} 箱线图已保存: {boxplot_vs_group_file}")

        # 保存 数值特征 vs. 分组标签 箱线图逻辑到文本
        boxplot_vs_group_insights_file = os.path.join(insights_dir, f'group_boxplot_vs_label_group_insights_{col}.txt') # insights 文件名包含 "group"
        with open(boxplot_vs_group_insights_file, 'w', encoding='utf-8') as f_insights:
            f_insights.write(f"分组 - 数值特征 {col} vs. 分组标签 {group_label_col} 箱线图分析:\n") # 文本内容包含 "分组"
            f_insights.write(f"  - 不同分组标签下 {col} 的分布差异: (请查看箱线图 {boxplot_vs_group_file} )\n")
            # ... (更详细的描述不同分组标签下的分布差异，与之前的代码类似，但针对 label_group) ...
            for group_value in sorted(data[group_label_col].unique()):
                group_data = data[data[group_label_col] == group_value][col].dropna()
                median_val = group_data.median()
                iqr_val = group_data.quantile(0.75) - group_data.quantile(0.25)
                f_insights.write(f"  - 分组标签 {group_value}: 中位数 (Median) = {median_val:.2f}, 四分位数范围 (IQR) = {iqr_val:.2f}\n")
            f_insights.write(f"  - 比较不同分组标签下 {col} 的中位数、IQR、异常值等，判断 {col} 是否在不同分组间有显著差异。\n")
        print(f"      - {col} vs. {group_label_col} 箱线图逻辑已保存: {boxplot_vs_group_file}")
        summary_content += f"\n4.3. 分组数据双变量分析 - 数值特征 vs. 分组标签 - {col} vs. {group_label_col} (详细逻辑见 {boxplot_vs_group_insights_file}, 图表见 {boxplot_vs_group_file}):\n"
        with open(boxplot_vs_group_insights_file, 'r', encoding='utf-8') as f_insight_read:
            summary_content += f_insight_read.read()


        # 类别特征 vs. label_group
        print("    - 类别特征 vs. label_group...")
        for col in group_categorical_features:
            if col in [label_col, group_label_col]:
                continue
            plt.figure(figsize=(8, 6))
            countplot_vs_group = sns.countplot(data=data, x=col, hue=group_label_col) # hue 为分组标签
            plt.title(f'分组 - 类别特征 vs. 分组标签 - {col} vs. {group_label_col}') # 标题包含 "分组"
            plt.xlabel(col)
            plt.ylabel('计数')
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            countplot_vs_group_file = os.path.join(group_dir, f'countplot_{col}_vs_group_label.png') # 保存到分组目录
            plt.savefig(countplot_vs_group_file)
            plt.close()
            print(f"      - {col} vs. {group_label_col} 柱状图已保存: {countplot_vs_group_file}") # 移动到循环内

            # 保存 类别特征 vs. 分组标签 柱状图逻辑到文本
            countplot_vs_group_insights_file = os.path.join(insights_dir, f'group_countplot_vs_label_group_insights_{col}.txt') # insights 文件名包含 "group"
            with open(countplot_vs_group_insights_file, 'w', encoding='utf-8') as f_insights:
                f_insights.write(f"分组 - 类别特征 {col} vs. 分组标签 {group_label_col} 柱状图分析:\n") # 文本内容包含 "分组"
                f_insights.write(f"  - 不同分组标签下 {col} 的类别分布差异: (请查看柱状图 {countplot_vs_group_file} )\n") # 移动到循环内
                # ... (更详细的描述不同分组标签下的类别分布差异，与之前的代码类似，但针对 label_group) ...
                for group_value in sorted(data[group_label_col].unique()):
                    f_insights.write(f"  - 分组标签 {group_value} 中 {col} 的类别分布:\n")
                    group_category_counts = data[data[group_label_col] == group_value][col].value_counts(normalize=True) * 100
                    f_insights.write(str(group_category_counts.round(2)) + "%\n") # 类别百分比
                f_insights.write(f"  - 观察不同分组标签中，{col} 各类别的比例差异，判断 {col} 是否在不同分组间有分布差异。\n") # 移动到循环内
            print(f"      - {col} vs. {group_label_col} 柱状图逻辑已保存: {countplot_vs_group_file}") # 移动到循环内
            summary_content += f"\n4.4. 分组数据双变量分析 - 类别特征 vs. 分组标签 - {col} vs. {group_label_col} (详细逻辑见 {countplot_vs_group_insights_file}, 图表见 {countplot_vs_group_file}):\n" # 移动到循环内
            with open(countplot_vs_group_insights_file, 'r', encoding='utf-8') as f_insight_read: # 移动到循环内
                summary_content += f_insight_read.read() # 移动到循环内


    # 7. 缺失值分析 (Missing Value Analysis) - 整体数据 (保持不变，因为缺失值分析是针对整体数据的)
    print("\n5. 缺失值分析 (Missing Value Analysis) - 整体数据...") # 步骤编号改为 5，因为前面增加了分组分析步骤
    missing_value_counts = data.isnull().sum().sort_values(ascending=False)
    missing_value_percentages = (data.isnull().sum() / len(data)).sort_values(ascending=False)
    missing_info = pd.concat([missing_value_counts, missing_value_percentages], axis=1, keys=['缺失值计数', '缺失值比例'])
    missing_value_analysis_file = os.path.join(overall_dir, 'missing_value_analysis.csv') # 保存到整体数据目录
    missing_info.to_csv(missing_value_analysis_file, encoding='utf-8')
    print(f"  - 整体数据缺失值统计已保存到: {missing_value_analysis_file}")

    # 保存缺失值分析逻辑到文本
    missing_insights_file = os.path.join(insights_dir, 'missing_value_insights.txt')
    with open(missing_insights_file, 'w', encoding='utf-8') as f_insights:
        f_insights.write(f"缺失值分析 - 整体数据:\n") # 文本内容包含 "整体数据"
        f_insights.write("  - 各列缺失值计数和比例 (详细信息见 missing_value_analysis.csv):\n")
        f_insights.write(str(missing_info) + "\n")
        # ... (更详细的缺失值描述，与之前的代码相同) ...
        top_missing_cols = missing_info[missing_info['缺失值比例'] > 0.1] # 例如 缺失比例 > 10% 的列
        if not top_missing_cols.empty:
            f_insights.write(f"  - 缺失值比例较高的列 (>= 10%):\n")
            f_insights.write(str(top_missing_cols) + "\n")
        else:
            f_insights.write(f"  - 无列缺失值比例高于 10%.\n")
        f_insights.write(f"  - 缺失值模式: (如果绘制了 missing_value_matrix.png，请查看矩阵了解缺失值是否呈现特定模式).\n")
    print(f"  - 整体数据缺失值逻辑已保存到: {missing_insights_file}")
    summary_content += f"\n5. 缺失值分析 - 整体数据 (详细逻辑见 {missing_insights_file}, 统计信息见 {missing_value_analysis_file}):\n"
    with open(missing_insights_file, 'r', encoding='utf-8') as f_insight_read:
        summary_content += f_insight_read.read()


    if HAS_MISSINGNO:
        print("  - 缺失值可视化 (如果 missingno 已安装)...")
        plt.figure(figsize=(10, 6))
        msno_matrix = msno.matrix(data)
        plt.title('缺失值模式矩阵')
        missing_value_matrix_file = os.path.join(overall_dir, 'missing_value_matrix.png') # 保存到整体数据目录
        plt.savefig(missing_value_matrix_file)
        plt.close()
        print(f"    - 缺失值矩阵可视化已保存: {missing_value_matrix_file}")

        plt.figure(figsize=(10, 6))
        msno_bar = msno.bar(data)
        plt.title('各列缺失值柱状图')
        missing_value_bar_file = os.path.join(overall_dir, 'missing_value_bar.png') # 保存到整体数据目录
        plt.savefig(missing_value_bar_file)
        plt.close()
        print(f"    - 缺失值柱状图可视化已保存: {missing_value_bar_file}")
        summary_content += f"\n5.1. 缺失值可视化 - 整体数据 (图表见 {missing_value_matrix_file}, {missing_value_bar_file}):\n" # 文本内容包含 "整体数据"
        summary_content += f"  - (请查看 {missing_value_matrix_file} 和 {missing_value_bar_file} 图片了解缺失值可视化信息)\n"
    else:
        print("  - 跳过缺失值可视化，因为 missingno 库未安装。")
        summary_content += "\n5.1. 缺失值可视化 - 整体数据: 跳过缺失值可视化，因为 missingno 库未安装。\n" # 文本内容包含 "整体数据"


    summary_content += "\n===================\nEDA 分析完成，详细结果已保存到目录: " + output_dir
    with open(summary_insights_file, 'w', encoding='utf-8') as f_summary:
        f_summary.write(summary_content)
    print(f"\nEDA 分析完成，结果已保存到目录: {output_dir}")
    print(f"  - 图片逻辑文本 insights 已保存到目录: {insights_dir}")
    print(f"  - **总的文本逻辑总结已保存到: {summary_insights_file}**")

perform_eda(eicu_data, label_col='label', output_dir='eicu_eda_results')
perform_eda(mimic_data, label_col='label', output_dir='mimic_eda_results')
# Out:
# 开始 EDA 分析，结果将保存到目录: eicu_eda_results
#
# 1. 数据概览 (Data Overview) - 整体数据...
#   - 整体数据概览信息已保存到: eicu_eda_results\overall\data_overview.txt
#
# 2. 描述性统计 (Descriptive Statistics) - 整体数据...
#   - 整体数据描述性统计信息已保存到: eicu_eda_results\overall\descriptive_statistics.csv
#
# 3. Label 0 单变量分析...
#   - 数值特征单变量分析...
#     - age 直方图已保存: eicu_eda_results\label_0\hist_age.png
#     - age 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_age.txt
#     - age 箱线图已保存: eicu_eda_results\label_0\boxplot_age.png
#     - age 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_age.txt
#     - gender_Male 直方图已保存: eicu_eda_results\label_0\hist_gender_Male.png
#     - gender_Male 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_gender_Male.txt
#     - gender_Male 箱线图已保存: eicu_eda_results\label_0\boxplot_gender_Male.png
#     - gender_Male 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_gender_Male.txt
#     - heartrate 直方图已保存: eicu_eda_results\label_0\hist_heartrate.png
#     - heartrate 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_heartrate.txt
#     - heartrate 箱线图已保存: eicu_eda_results\label_0\boxplot_heartrate.png
#     - heartrate 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_heartrate.txt
#     - height 直方图已保存: eicu_eda_results\label_0\hist_height.png
#     - height 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_height.txt
#     - height 箱线图已保存: eicu_eda_results\label_0\boxplot_height.png
#     - height 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_height.txt
#     - ibp_diastolic 直方图已保存: eicu_eda_results\label_0\hist_ibp_diastolic.png
#     - ibp_diastolic 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_ibp_diastolic.txt
#     - ibp_diastolic 箱线图已保存: eicu_eda_results\label_0\boxplot_ibp_diastolic.png
#     - ibp_diastolic 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_ibp_diastolic.txt
#     - ibp_mean 直方图已保存: eicu_eda_results\label_0\hist_ibp_mean.png
#     - ibp_mean 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_ibp_mean.txt
#     - ibp_mean 箱线图已保存: eicu_eda_results\label_0\boxplot_ibp_mean.png
#     - ibp_mean 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_ibp_mean.txt
#     - ibp_systolic 直方图已保存: eicu_eda_results\label_0\hist_ibp_systolic.png
#     - ibp_systolic 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_ibp_systolic.txt
#     - ibp_systolic 箱线图已保存: eicu_eda_results\label_0\boxplot_ibp_systolic.png
#     - ibp_systolic 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_ibp_systolic.txt
#     - labalbumin 直方图已保存: eicu_eda_results\label_0\hist_labalbumin.png
#     - labalbumin 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labalbumin.txt
#     - labalbumin 箱线图已保存: eicu_eda_results\label_0\boxplot_labalbumin.png
#     - labalbumin 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labalbumin.txt
#     - labalt 直方图已保存: eicu_eda_results\label_0\hist_labalt.png
#     - labalt 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labalt.txt
#     - labalt 箱线图已保存: eicu_eda_results\label_0\boxplot_labalt.png
#     - labalt 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labalt.txt
#     - labaniongap 直方图已保存: eicu_eda_results\label_0\hist_labaniongap.png
#     - labaniongap 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labaniongap.txt
#     - labaniongap 箱线图已保存: eicu_eda_results\label_0\boxplot_labaniongap.png
#     - labaniongap 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labaniongap.txt
#     - labast 直方图已保存: eicu_eda_results\label_0\hist_labast.png
#     - labast 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labast.txt
#     - labast 箱线图已保存: eicu_eda_results\label_0\boxplot_labast.png
#     - labast 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labast.txt
#     - labbedglucose 直方图已保存: eicu_eda_results\label_0\hist_labbedglucose.png
#     - labbedglucose 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labbedglucose.txt
#     - labbedglucose 箱线图已保存: eicu_eda_results\label_0\boxplot_labbedglucose.png
#     - labbedglucose 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labbedglucose.txt
#     - labbun 直方图已保存: eicu_eda_results\label_0\hist_labbun.png
#     - labbun 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labbun.txt
#     - labbun 箱线图已保存: eicu_eda_results\label_0\boxplot_labbun.png
#     - labbun 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labbun.txt
#     - labcalcium 直方图已保存: eicu_eda_results\label_0\hist_labcalcium.png
#     - labcalcium 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labcalcium.txt
#     - labcalcium 箱线图已保存: eicu_eda_results\label_0\boxplot_labcalcium.png
#     - labcalcium 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labcalcium.txt
#     - labchloride 直方图已保存: eicu_eda_results\label_0\hist_labchloride.png
#     - labchloride 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labchloride.txt
#     - labchloride 箱线图已保存: eicu_eda_results\label_0\boxplot_labchloride.png
#     - labchloride 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labchloride.txt
#     - labcreatinine 直方图已保存: eicu_eda_results\label_0\hist_labcreatinine.png
#     - labcreatinine 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labcreatinine.txt
#     - labcreatinine 箱线图已保存: eicu_eda_results\label_0\boxplot_labcreatinine.png
#     - labcreatinine 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labcreatinine.txt
#     - labfreecalcium 直方图已保存: eicu_eda_results\label_0\hist_labfreecalcium.png
#     - labfreecalcium 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labfreecalcium.txt
#     - labfreecalcium 箱线图已保存: eicu_eda_results\label_0\boxplot_labfreecalcium.png
#     - labfreecalcium 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labfreecalcium.txt
#     - labhct 直方图已保存: eicu_eda_results\label_0\hist_labhct.png
#     - labhct 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labhct.txt
#     - labhct 箱线图已保存: eicu_eda_results\label_0\boxplot_labhct.png
#     - labhct 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labhct.txt
#     - labhgb 直方图已保存: eicu_eda_results\label_0\hist_labhgb.png
#     - labhgb 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labhgb.txt
#     - labhgb 箱线图已保存: eicu_eda_results\label_0\boxplot_labhgb.png
#     - labhgb 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labhgb.txt
#     - lablactate 直方图已保存: eicu_eda_results\label_0\hist_lablactate.png
#     - lablactate 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_lablactate.txt
#     - lablactate 箱线图已保存: eicu_eda_results\label_0\boxplot_lablactate.png
#     - lablactate 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_lablactate.txt
#     - lablymphocytes 直方图已保存: eicu_eda_results\label_0\hist_lablymphocytes.png
#     - lablymphocytes 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_lablymphocytes.txt
#     - lablymphocytes 箱线图已保存: eicu_eda_results\label_0\boxplot_lablymphocytes.png
#     - lablymphocytes 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_lablymphocytes.txt
#     - labneutrophilcount 直方图已保存: eicu_eda_results\label_0\hist_labneutrophilcount.png
#     - labneutrophilcount 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labneutrophilcount.txt
#     - labneutrophilcount 箱线图已保存: eicu_eda_results\label_0\boxplot_labneutrophilcount.png
#     - labneutrophilcount 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labneutrophilcount.txt
#     - labpco2 直方图已保存: eicu_eda_results\label_0\hist_labpco2.png
#     - labpco2 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labpco2.txt
#     - labpco2 箱线图已保存: eicu_eda_results\label_0\boxplot_labpco2.png
#     - labpco2 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labpco2.txt
#     - labph 直方图已保存: eicu_eda_results\label_0\hist_labph.png
#     - labph 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labph.txt
#     - labph 箱线图已保存: eicu_eda_results\label_0\boxplot_labph.png
#     - labph 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labph.txt
#     - labplateletcount 直方图已保存: eicu_eda_results\label_0\hist_labplateletcount.png
#     - labplateletcount 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labplateletcount.txt
#     - labplateletcount 箱线图已保存: eicu_eda_results\label_0\boxplot_labplateletcount.png
#     - labplateletcount 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labplateletcount.txt
#     - labpo2 直方图已保存: eicu_eda_results\label_0\hist_labpo2.png
#     - labpo2 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labpo2.txt
#     - labpo2 箱线图已保存: eicu_eda_results\label_0\boxplot_labpo2.png
#     - labpo2 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labpo2.txt
#     - labpotassium 直方图已保存: eicu_eda_results\label_0\hist_labpotassium.png
#     - labpotassium 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labpotassium.txt
#     - labpotassium 箱线图已保存: eicu_eda_results\label_0\boxplot_labpotassium.png
#     - labpotassium 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labpotassium.txt
#     - labpt 直方图已保存: eicu_eda_results\label_0\hist_labpt.png
#     - labpt 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labpt.txt
#     - labpt 箱线图已保存: eicu_eda_results\label_0\boxplot_labpt.png
#     - labpt 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labpt.txt
#     - labptinr 直方图已保存: eicu_eda_results\label_0\hist_labptinr.png
#     - labptinr 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labptinr.txt
#     - labptinr 箱线图已保存: eicu_eda_results\label_0\boxplot_labptinr.png
#     - labptinr 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labptinr.txt
#     - labptt 直方图已保存: eicu_eda_results\label_0\hist_labptt.png
#     - labptt 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labptt.txt
#     - labptt 箱线图已保存: eicu_eda_results\label_0\boxplot_labptt.png
#     - labptt 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labptt.txt
#     - labrbc 直方图已保存: eicu_eda_results\label_0\hist_labrbc.png
#     - labrbc 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labrbc.txt
#     - labrbc 箱线图已保存: eicu_eda_results\label_0\boxplot_labrbc.png
#     - labrbc 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labrbc.txt
#     - labrdw 直方图已保存: eicu_eda_results\label_0\hist_labrdw.png
#     - labrdw 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labrdw.txt
#     - labrdw 箱线图已保存: eicu_eda_results\label_0\boxplot_labrdw.png
#     - labrdw 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labrdw.txt
#     - labsodium 直方图已保存: eicu_eda_results\label_0\hist_labsodium.png
#     - labsodium 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labsodium.txt
#     - labsodium 箱线图已保存: eicu_eda_results\label_0\boxplot_labsodium.png
#     - labsodium 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labsodium.txt
#     - labtotalbilirubin 直方图已保存: eicu_eda_results\label_0\hist_labtotalbilirubin.png
#     - labtotalbilirubin 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labtotalbilirubin.txt
#     - labtotalbilirubin 箱线图已保存: eicu_eda_results\label_0\boxplot_labtotalbilirubin.png
#     - labtotalbilirubin 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labtotalbilirubin.txt
#     - labtotalco2 直方图已保存: eicu_eda_results\label_0\hist_labtotalco2.png
#     - labtotalco2 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labtotalco2.txt
#     - labtotalco2 箱线图已保存: eicu_eda_results\label_0\boxplot_labtotalco2.png
#     - labtotalco2 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labtotalco2.txt
#     - labwbc 直方图已保存: eicu_eda_results\label_0\hist_labwbc.png
#     - labwbc 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_labwbc.txt
#     - labwbc 箱线图已保存: eicu_eda_results\label_0\boxplot_labwbc.png
#     - labwbc 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_labwbc.txt
#     - nibp_diastolic 直方图已保存: eicu_eda_results\label_0\hist_nibp_diastolic.png
#     - nibp_diastolic 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_nibp_diastolic.txt
#     - nibp_diastolic 箱线图已保存: eicu_eda_results\label_0\boxplot_nibp_diastolic.png
#     - nibp_diastolic 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_nibp_diastolic.txt
#     - nibp_mean 直方图已保存: eicu_eda_results\label_0\hist_nibp_mean.png
#     - nibp_mean 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_nibp_mean.txt
#     - nibp_mean 箱线图已保存: eicu_eda_results\label_0\boxplot_nibp_mean.png
#     - nibp_mean 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_nibp_mean.txt
#     - nibp_systolic 直方图已保存: eicu_eda_results\label_0\hist_nibp_systolic.png
#     - nibp_systolic 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_nibp_systolic.txt
#     - nibp_systolic 箱线图已保存: eicu_eda_results\label_0\boxplot_nibp_systolic.png
#     - nibp_systolic 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_nibp_systolic.txt
#     - respiratoryrate 直方图已保存: eicu_eda_results\label_0\hist_respiratoryrate.png
#     - respiratoryrate 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_respiratoryrate.txt
#     - respiratoryrate 箱线图已保存: eicu_eda_results\label_0\boxplot_respiratoryrate.png
#     - respiratoryrate 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_respiratoryrate.txt
#     - spo2 直方图已保存: eicu_eda_results\label_0\hist_spo2.png
#     - spo2 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_spo2.txt
#     - spo2 箱线图已保存: eicu_eda_results\label_0\boxplot_spo2.png
#     - spo2 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_spo2.txt
#     - temperature 直方图已保存: eicu_eda_results\label_0\hist_temperature.png
#     - temperature 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_temperature.txt
#     - temperature 箱线图已保存: eicu_eda_results\label_0\boxplot_temperature.png
#     - temperature 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_temperature.txt
#     - weight 直方图已保存: eicu_eda_results\label_0\hist_weight.png
#     - weight 直方图逻辑已保存: eicu_eda_results\insights\label_0_hist_insights_weight.txt
#     - weight 箱线图已保存: eicu_eda_results\label_0\boxplot_weight.png
#     - weight 箱线图逻辑已保存: eicu_eda_results\insights\label_0_boxplot_insights_weight.txt
#   - 类别特征单变量分析...
#
# 3. Label 1 单变量分析...
#   - 数值特征单变量分析...
#     - age 直方图已保存: eicu_eda_results\label_1\hist_age.png
#     - age 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_age.txt
#     - age 箱线图已保存: eicu_eda_results\label_1\boxplot_age.png
#     - age 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_age.txt
#     - gender_Male 直方图已保存: eicu_eda_results\label_1\hist_gender_Male.png
#     - gender_Male 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_gender_Male.txt
#     - gender_Male 箱线图已保存: eicu_eda_results\label_1\boxplot_gender_Male.png
#     - gender_Male 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_gender_Male.txt
#     - heartrate 直方图已保存: eicu_eda_results\label_1\hist_heartrate.png
#     - heartrate 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_heartrate.txt
#     - heartrate 箱线图已保存: eicu_eda_results\label_1\boxplot_heartrate.png
#     - heartrate 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_heartrate.txt
#     - height 直方图已保存: eicu_eda_results\label_1\hist_height.png
#     - height 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_height.txt
#     - height 箱线图已保存: eicu_eda_results\label_1\boxplot_height.png
#     - height 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_height.txt
#     - ibp_diastolic 直方图已保存: eicu_eda_results\label_1\hist_ibp_diastolic.png
#     - ibp_diastolic 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_ibp_diastolic.txt
#     - ibp_diastolic 箱线图已保存: eicu_eda_results\label_1\boxplot_ibp_diastolic.png
#     - ibp_diastolic 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_ibp_diastolic.txt
#     - ibp_mean 直方图已保存: eicu_eda_results\label_1\hist_ibp_mean.png
#     - ibp_mean 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_ibp_mean.txt
#     - ibp_mean 箱线图已保存: eicu_eda_results\label_1\boxplot_ibp_mean.png
#     - ibp_mean 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_ibp_mean.txt
#     - ibp_systolic 直方图已保存: eicu_eda_results\label_1\hist_ibp_systolic.png
#     - ibp_systolic 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_ibp_systolic.txt
#     - ibp_systolic 箱线图已保存: eicu_eda_results\label_1\boxplot_ibp_systolic.png
#     - ibp_systolic 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_ibp_systolic.txt
#     - labalbumin 直方图已保存: eicu_eda_results\label_1\hist_labalbumin.png
#     - labalbumin 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labalbumin.txt
#     - labalbumin 箱线图已保存: eicu_eda_results\label_1\boxplot_labalbumin.png
#     - labalbumin 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labalbumin.txt
#     - labalt 直方图已保存: eicu_eda_results\label_1\hist_labalt.png
#     - labalt 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labalt.txt
#     - labalt 箱线图已保存: eicu_eda_results\label_1\boxplot_labalt.png
#     - labalt 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labalt.txt
#     - labaniongap 直方图已保存: eicu_eda_results\label_1\hist_labaniongap.png
#     - labaniongap 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labaniongap.txt
#     - labaniongap 箱线图已保存: eicu_eda_results\label_1\boxplot_labaniongap.png
#     - labaniongap 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labaniongap.txt
#     - labast 直方图已保存: eicu_eda_results\label_1\hist_labast.png
#     - labast 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labast.txt
#     - labast 箱线图已保存: eicu_eda_results\label_1\boxplot_labast.png
#     - labast 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labast.txt
#     - labbedglucose 直方图已保存: eicu_eda_results\label_1\hist_labbedglucose.png
#     - labbedglucose 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labbedglucose.txt
#     - labbedglucose 箱线图已保存: eicu_eda_results\label_1\boxplot_labbedglucose.png
#     - labbedglucose 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labbedglucose.txt
#     - labbun 直方图已保存: eicu_eda_results\label_1\hist_labbun.png
#     - labbun 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labbun.txt
#     - labbun 箱线图已保存: eicu_eda_results\label_1\boxplot_labbun.png
#     - labbun 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labbun.txt
#     - labcalcium 直方图已保存: eicu_eda_results\label_1\hist_labcalcium.png
#     - labcalcium 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labcalcium.txt
#     - labcalcium 箱线图已保存: eicu_eda_results\label_1\boxplot_labcalcium.png
#     - labcalcium 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labcalcium.txt
#     - labchloride 直方图已保存: eicu_eda_results\label_1\hist_labchloride.png
#     - labchloride 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labchloride.txt
#     - labchloride 箱线图已保存: eicu_eda_results\label_1\boxplot_labchloride.png
#     - labchloride 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labchloride.txt
#     - labcreatinine 直方图已保存: eicu_eda_results\label_1\hist_labcreatinine.png
#     - labcreatinine 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labcreatinine.txt
#     - labcreatinine 箱线图已保存: eicu_eda_results\label_1\boxplot_labcreatinine.png
#     - labcreatinine 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labcreatinine.txt
#     - labfreecalcium 直方图已保存: eicu_eda_results\label_1\hist_labfreecalcium.png
#     - labfreecalcium 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labfreecalcium.txt
#     - labfreecalcium 箱线图已保存: eicu_eda_results\label_1\boxplot_labfreecalcium.png
#     - labfreecalcium 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labfreecalcium.txt
#     - labhct 直方图已保存: eicu_eda_results\label_1\hist_labhct.png
#     - labhct 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labhct.txt
#     - labhct 箱线图已保存: eicu_eda_results\label_1\boxplot_labhct.png
#     - labhct 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labhct.txt
#     - labhgb 直方图已保存: eicu_eda_results\label_1\hist_labhgb.png
#     - labhgb 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labhgb.txt
#     - labhgb 箱线图已保存: eicu_eda_results\label_1\boxplot_labhgb.png
#     - labhgb 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labhgb.txt
#     - lablactate 直方图已保存: eicu_eda_results\label_1\hist_lablactate.png
#     - lablactate 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_lablactate.txt
#     - lablactate 箱线图已保存: eicu_eda_results\label_1\boxplot_lablactate.png
#     - lablactate 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_lablactate.txt
#     - lablymphocytes 直方图已保存: eicu_eda_results\label_1\hist_lablymphocytes.png
#     - lablymphocytes 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_lablymphocytes.txt
#     - lablymphocytes 箱线图已保存: eicu_eda_results\label_1\boxplot_lablymphocytes.png
#     - lablymphocytes 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_lablymphocytes.txt
#     - labneutrophilcount 直方图已保存: eicu_eda_results\label_1\hist_labneutrophilcount.png
#     - labneutrophilcount 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labneutrophilcount.txt
#     - labneutrophilcount 箱线图已保存: eicu_eda_results\label_1\boxplot_labneutrophilcount.png
#     - labneutrophilcount 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labneutrophilcount.txt
#     - labpco2 直方图已保存: eicu_eda_results\label_1\hist_labpco2.png
#     - labpco2 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labpco2.txt
#     - labpco2 箱线图已保存: eicu_eda_results\label_1\boxplot_labpco2.png
#     - labpco2 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labpco2.txt
#     - labph 直方图已保存: eicu_eda_results\label_1\hist_labph.png
#     - labph 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labph.txt
#     - labph 箱线图已保存: eicu_eda_results\label_1\boxplot_labph.png
#     - labph 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labph.txt
#     - labplateletcount 直方图已保存: eicu_eda_results\label_1\hist_labplateletcount.png
#     - labplateletcount 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labplateletcount.txt
#     - labplateletcount 箱线图已保存: eicu_eda_results\label_1\boxplot_labplateletcount.png
#     - labplateletcount 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labplateletcount.txt
#     - labpo2 直方图已保存: eicu_eda_results\label_1\hist_labpo2.png
#     - labpo2 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labpo2.txt
#     - labpo2 箱线图已保存: eicu_eda_results\label_1\boxplot_labpo2.png
#     - labpo2 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labpo2.txt
#     - labpotassium 直方图已保存: eicu_eda_results\label_1\hist_labpotassium.png
#     - labpotassium 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labpotassium.txt
#     - labpotassium 箱线图已保存: eicu_eda_results\label_1\boxplot_labpotassium.png
#     - labpotassium 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labpotassium.txt
#     - labpt 直方图已保存: eicu_eda_results\label_1\hist_labpt.png
#     - labpt 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labpt.txt
#     - labpt 箱线图已保存: eicu_eda_results\label_1\boxplot_labpt.png
#     - labpt 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labpt.txt
#     - labptinr 直方图已保存: eicu_eda_results\label_1\hist_labptinr.png
#     - labptinr 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labptinr.txt
#     - labptinr 箱线图已保存: eicu_eda_results\label_1\boxplot_labptinr.png
#     - labptinr 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labptinr.txt
#     - labptt 直方图已保存: eicu_eda_results\label_1\hist_labptt.png
#     - labptt 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labptt.txt
#     - labptt 箱线图已保存: eicu_eda_results\label_1\boxplot_labptt.png
#     - labptt 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labptt.txt
#     - labrbc 直方图已保存: eicu_eda_results\label_1\hist_labrbc.png
#     - labrbc 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labrbc.txt
#     - labrbc 箱线图已保存: eicu_eda_results\label_1\boxplot_labrbc.png
#     - labrbc 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labrbc.txt
#     - labrdw 直方图已保存: eicu_eda_results\label_1\hist_labrdw.png
#     - labrdw 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labrdw.txt
#     - labrdw 箱线图已保存: eicu_eda_results\label_1\boxplot_labrdw.png
#     - labrdw 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labrdw.txt
#     - labsodium 直方图已保存: eicu_eda_results\label_1\hist_labsodium.png
#     - labsodium 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labsodium.txt
#     - labsodium 箱线图已保存: eicu_eda_results\label_1\boxplot_labsodium.png
#     - labsodium 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labsodium.txt
#     - labtotalbilirubin 直方图已保存: eicu_eda_results\label_1\hist_labtotalbilirubin.png
#     - labtotalbilirubin 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labtotalbilirubin.txt
#     - labtotalbilirubin 箱线图已保存: eicu_eda_results\label_1\boxplot_labtotalbilirubin.png
#     - labtotalbilirubin 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labtotalbilirubin.txt
#     - labtotalco2 直方图已保存: eicu_eda_results\label_1\hist_labtotalco2.png
#     - labtotalco2 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labtotalco2.txt
#     - labtotalco2 箱线图已保存: eicu_eda_results\label_1\boxplot_labtotalco2.png
#     - labtotalco2 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labtotalco2.txt
#     - labwbc 直方图已保存: eicu_eda_results\label_1\hist_labwbc.png
#     - labwbc 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_labwbc.txt
#     - labwbc 箱线图已保存: eicu_eda_results\label_1\boxplot_labwbc.png
#     - labwbc 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_labwbc.txt
#     - nibp_diastolic 直方图已保存: eicu_eda_results\label_1\hist_nibp_diastolic.png
#     - nibp_diastolic 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_nibp_diastolic.txt
#     - nibp_diastolic 箱线图已保存: eicu_eda_results\label_1\boxplot_nibp_diastolic.png
#     - nibp_diastolic 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_nibp_diastolic.txt
#     - nibp_mean 直方图已保存: eicu_eda_results\label_1\hist_nibp_mean.png
#     - nibp_mean 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_nibp_mean.txt
#     - nibp_mean 箱线图已保存: eicu_eda_results\label_1\boxplot_nibp_mean.png
#     - nibp_mean 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_nibp_mean.txt
#     - nibp_systolic 直方图已保存: eicu_eda_results\label_1\hist_nibp_systolic.png
#     - nibp_systolic 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_nibp_systolic.txt
#     - nibp_systolic 箱线图已保存: eicu_eda_results\label_1\boxplot_nibp_systolic.png
#     - nibp_systolic 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_nibp_systolic.txt
#     - respiratoryrate 直方图已保存: eicu_eda_results\label_1\hist_respiratoryrate.png
#     - respiratoryrate 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_respiratoryrate.txt
#     - respiratoryrate 箱线图已保存: eicu_eda_results\label_1\boxplot_respiratoryrate.png
#     - respiratoryrate 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_respiratoryrate.txt
#     - spo2 直方图已保存: eicu_eda_results\label_1\hist_spo2.png
#     - spo2 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_spo2.txt
#     - spo2 箱线图已保存: eicu_eda_results\label_1\boxplot_spo2.png
#     - spo2 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_spo2.txt
#     - temperature 直方图已保存: eicu_eda_results\label_1\hist_temperature.png
#     - temperature 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_temperature.txt
#     - temperature 箱线图已保存: eicu_eda_results\label_1\boxplot_temperature.png
#     - temperature 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_temperature.txt
#     - weight 直方图已保存: eicu_eda_results\label_1\hist_weight.png
#     - weight 直方图逻辑已保存: eicu_eda_results\insights\label_1_hist_insights_weight.txt
#     - weight 箱线图已保存: eicu_eda_results\label_1\boxplot_weight.png
#     - weight 箱线图逻辑已保存: eicu_eda_results\insights\label_1_boxplot_insights_weight.txt
#   - 类别特征单变量分析...
#
# 3. Label 2 单变量分析...
#   - 数值特征单变量分析...
#     - age 直方图已保存: eicu_eda_results\label_2\hist_age.png
#     - age 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_age.txt
#     - age 箱线图已保存: eicu_eda_results\label_2\boxplot_age.png
#     - age 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_age.txt
#     - gender_Male 直方图已保存: eicu_eda_results\label_2\hist_gender_Male.png
#     - gender_Male 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_gender_Male.txt
#     - gender_Male 箱线图已保存: eicu_eda_results\label_2\boxplot_gender_Male.png
#     - gender_Male 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_gender_Male.txt
#     - heartrate 直方图已保存: eicu_eda_results\label_2\hist_heartrate.png
#     - heartrate 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_heartrate.txt
#     - heartrate 箱线图已保存: eicu_eda_results\label_2\boxplot_heartrate.png
#     - heartrate 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_heartrate.txt
#     - height 直方图已保存: eicu_eda_results\label_2\hist_height.png
#     - height 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_height.txt
#     - height 箱线图已保存: eicu_eda_results\label_2\boxplot_height.png
#     - height 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_height.txt
#     - ibp_diastolic 直方图已保存: eicu_eda_results\label_2\hist_ibp_diastolic.png
#     - ibp_diastolic 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_ibp_diastolic.txt
#     - ibp_diastolic 箱线图已保存: eicu_eda_results\label_2\boxplot_ibp_diastolic.png
#     - ibp_diastolic 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_ibp_diastolic.txt
#     - ibp_mean 直方图已保存: eicu_eda_results\label_2\hist_ibp_mean.png
#     - ibp_mean 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_ibp_mean.txt
#     - ibp_mean 箱线图已保存: eicu_eda_results\label_2\boxplot_ibp_mean.png
#     - ibp_mean 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_ibp_mean.txt
#     - ibp_systolic 直方图已保存: eicu_eda_results\label_2\hist_ibp_systolic.png
#     - ibp_systolic 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_ibp_systolic.txt
#     - ibp_systolic 箱线图已保存: eicu_eda_results\label_2\boxplot_ibp_systolic.png
#     - ibp_systolic 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_ibp_systolic.txt
#     - labalbumin 直方图已保存: eicu_eda_results\label_2\hist_labalbumin.png
#     - labalbumin 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labalbumin.txt
#     - labalbumin 箱线图已保存: eicu_eda_results\label_2\boxplot_labalbumin.png
#     - labalbumin 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labalbumin.txt
#     - labalt 直方图已保存: eicu_eda_results\label_2\hist_labalt.png
#     - labalt 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labalt.txt
#     - labalt 箱线图已保存: eicu_eda_results\label_2\boxplot_labalt.png
#     - labalt 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labalt.txt
#     - labaniongap 直方图已保存: eicu_eda_results\label_2\hist_labaniongap.png
#     - labaniongap 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labaniongap.txt
#     - labaniongap 箱线图已保存: eicu_eda_results\label_2\boxplot_labaniongap.png
#     - labaniongap 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labaniongap.txt
#     - labast 直方图已保存: eicu_eda_results\label_2\hist_labast.png
#     - labast 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labast.txt
#     - labast 箱线图已保存: eicu_eda_results\label_2\boxplot_labast.png
#     - labast 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labast.txt
#     - labbedglucose 直方图已保存: eicu_eda_results\label_2\hist_labbedglucose.png
#     - labbedglucose 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labbedglucose.txt
#     - labbedglucose 箱线图已保存: eicu_eda_results\label_2\boxplot_labbedglucose.png
#     - labbedglucose 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labbedglucose.txt
#     - labbun 直方图已保存: eicu_eda_results\label_2\hist_labbun.png
#     - labbun 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labbun.txt
#     - labbun 箱线图已保存: eicu_eda_results\label_2\boxplot_labbun.png
#     - labbun 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labbun.txt
#     - labcalcium 直方图已保存: eicu_eda_results\label_2\hist_labcalcium.png
#     - labcalcium 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labcalcium.txt
#     - labcalcium 箱线图已保存: eicu_eda_results\label_2\boxplot_labcalcium.png
#     - labcalcium 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labcalcium.txt
#     - labchloride 直方图已保存: eicu_eda_results\label_2\hist_labchloride.png
#     - labchloride 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labchloride.txt
#     - labchloride 箱线图已保存: eicu_eda_results\label_2\boxplot_labchloride.png
#     - labchloride 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labchloride.txt
#     - labcreatinine 直方图已保存: eicu_eda_results\label_2\hist_labcreatinine.png
#     - labcreatinine 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labcreatinine.txt
#     - labcreatinine 箱线图已保存: eicu_eda_results\label_2\boxplot_labcreatinine.png
#     - labcreatinine 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labcreatinine.txt
#     - labfreecalcium 直方图已保存: eicu_eda_results\label_2\hist_labfreecalcium.png
#     - labfreecalcium 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labfreecalcium.txt
#     - labfreecalcium 箱线图已保存: eicu_eda_results\label_2\boxplot_labfreecalcium.png
#     - labfreecalcium 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labfreecalcium.txt
#     - labhct 直方图已保存: eicu_eda_results\label_2\hist_labhct.png
#     - labhct 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labhct.txt
#     - labhct 箱线图已保存: eicu_eda_results\label_2\boxplot_labhct.png
#     - labhct 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labhct.txt
#     - labhgb 直方图已保存: eicu_eda_results\label_2\hist_labhgb.png
#     - labhgb 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labhgb.txt
#     - labhgb 箱线图已保存: eicu_eda_results\label_2\boxplot_labhgb.png
#     - labhgb 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labhgb.txt
#     - lablactate 直方图已保存: eicu_eda_results\label_2\hist_lablactate.png
#     - lablactate 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_lablactate.txt
#     - lablactate 箱线图已保存: eicu_eda_results\label_2\boxplot_lablactate.png
#     - lablactate 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_lablactate.txt
#     - lablymphocytes 直方图已保存: eicu_eda_results\label_2\hist_lablymphocytes.png
#     - lablymphocytes 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_lablymphocytes.txt
#     - lablymphocytes 箱线图已保存: eicu_eda_results\label_2\boxplot_lablymphocytes.png
#     - lablymphocytes 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_lablymphocytes.txt
#     - labneutrophilcount 直方图已保存: eicu_eda_results\label_2\hist_labneutrophilcount.png
#     - labneutrophilcount 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labneutrophilcount.txt
#     - labneutrophilcount 箱线图已保存: eicu_eda_results\label_2\boxplot_labneutrophilcount.png
#     - labneutrophilcount 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labneutrophilcount.txt
#     - labpco2 直方图已保存: eicu_eda_results\label_2\hist_labpco2.png
#     - labpco2 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labpco2.txt
#     - labpco2 箱线图已保存: eicu_eda_results\label_2\boxplot_labpco2.png
#     - labpco2 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labpco2.txt
#     - labph 直方图已保存: eicu_eda_results\label_2\hist_labph.png
#     - labph 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labph.txt
#     - labph 箱线图已保存: eicu_eda_results\label_2\boxplot_labph.png
#     - labph 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labph.txt
#     - labplateletcount 直方图已保存: eicu_eda_results\label_2\hist_labplateletcount.png
#     - labplateletcount 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labplateletcount.txt
#     - labplateletcount 箱线图已保存: eicu_eda_results\label_2\boxplot_labplateletcount.png
#     - labplateletcount 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labplateletcount.txt
#     - labpo2 直方图已保存: eicu_eda_results\label_2\hist_labpo2.png
#     - labpo2 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labpo2.txt
#     - labpo2 箱线图已保存: eicu_eda_results\label_2\boxplot_labpo2.png
#     - labpo2 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labpo2.txt
#     - labpotassium 直方图已保存: eicu_eda_results\label_2\hist_labpotassium.png
#     - labpotassium 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labpotassium.txt
#     - labpotassium 箱线图已保存: eicu_eda_results\label_2\boxplot_labpotassium.png
#     - labpotassium 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labpotassium.txt
#     - labpt 直方图已保存: eicu_eda_results\label_2\hist_labpt.png
#     - labpt 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labpt.txt
#     - labpt 箱线图已保存: eicu_eda_results\label_2\boxplot_labpt.png
#     - labpt 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labpt.txt
#     - labptinr 直方图已保存: eicu_eda_results\label_2\hist_labptinr.png
#     - labptinr 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labptinr.txt
#     - labptinr 箱线图已保存: eicu_eda_results\label_2\boxplot_labptinr.png
#     - labptinr 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labptinr.txt
#     - labptt 直方图已保存: eicu_eda_results\label_2\hist_labptt.png
#     - labptt 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labptt.txt
#     - labptt 箱线图已保存: eicu_eda_results\label_2\boxplot_labptt.png
#     - labptt 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labptt.txt
#     - labrbc 直方图已保存: eicu_eda_results\label_2\hist_labrbc.png
#     - labrbc 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labrbc.txt
#     - labrbc 箱线图已保存: eicu_eda_results\label_2\boxplot_labrbc.png
#     - labrbc 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labrbc.txt
#     - labrdw 直方图已保存: eicu_eda_results\label_2\hist_labrdw.png
#     - labrdw 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labrdw.txt
#     - labrdw 箱线图已保存: eicu_eda_results\label_2\boxplot_labrdw.png
#     - labrdw 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labrdw.txt
#     - labsodium 直方图已保存: eicu_eda_results\label_2\hist_labsodium.png
#     - labsodium 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labsodium.txt
#     - labsodium 箱线图已保存: eicu_eda_results\label_2\boxplot_labsodium.png
#     - labsodium 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labsodium.txt
#     - labtotalbilirubin 直方图已保存: eicu_eda_results\label_2\hist_labtotalbilirubin.png
#     - labtotalbilirubin 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labtotalbilirubin.txt
#     - labtotalbilirubin 箱线图已保存: eicu_eda_results\label_2\boxplot_labtotalbilirubin.png
#     - labtotalbilirubin 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labtotalbilirubin.txt
#     - labtotalco2 直方图已保存: eicu_eda_results\label_2\hist_labtotalco2.png
#     - labtotalco2 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labtotalco2.txt
#     - labtotalco2 箱线图已保存: eicu_eda_results\label_2\boxplot_labtotalco2.png
#     - labtotalco2 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labtotalco2.txt
#     - labwbc 直方图已保存: eicu_eda_results\label_2\hist_labwbc.png
#     - labwbc 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_labwbc.txt
#     - labwbc 箱线图已保存: eicu_eda_results\label_2\boxplot_labwbc.png
#     - labwbc 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_labwbc.txt
#     - nibp_diastolic 直方图已保存: eicu_eda_results\label_2\hist_nibp_diastolic.png
#     - nibp_diastolic 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_nibp_diastolic.txt
#     - nibp_diastolic 箱线图已保存: eicu_eda_results\label_2\boxplot_nibp_diastolic.png
#     - nibp_diastolic 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_nibp_diastolic.txt
#     - nibp_mean 直方图已保存: eicu_eda_results\label_2\hist_nibp_mean.png
#     - nibp_mean 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_nibp_mean.txt
#     - nibp_mean 箱线图已保存: eicu_eda_results\label_2\boxplot_nibp_mean.png
#     - nibp_mean 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_nibp_mean.txt
#     - nibp_systolic 直方图已保存: eicu_eda_results\label_2\hist_nibp_systolic.png
#     - nibp_systolic 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_nibp_systolic.txt
#     - nibp_systolic 箱线图已保存: eicu_eda_results\label_2\boxplot_nibp_systolic.png
#     - nibp_systolic 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_nibp_systolic.txt
#     - respiratoryrate 直方图已保存: eicu_eda_results\label_2\hist_respiratoryrate.png
#     - respiratoryrate 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_respiratoryrate.txt
#     - respiratoryrate 箱线图已保存: eicu_eda_results\label_2\boxplot_respiratoryrate.png
#     - respiratoryrate 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_respiratoryrate.txt
#     - spo2 直方图已保存: eicu_eda_results\label_2\hist_spo2.png
#     - spo2 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_spo2.txt
#     - spo2 箱线图已保存: eicu_eda_results\label_2\boxplot_spo2.png
#     - spo2 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_spo2.txt
#     - temperature 直方图已保存: eicu_eda_results\label_2\hist_temperature.png
#     - temperature 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_temperature.txt
#     - temperature 箱线图已保存: eicu_eda_results\label_2\boxplot_temperature.png
#     - temperature 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_temperature.txt
#     - weight 直方图已保存: eicu_eda_results\label_2\hist_weight.png
#     - weight 直方图逻辑已保存: eicu_eda_results\insights\label_2_hist_insights_weight.txt
#     - weight 箱线图已保存: eicu_eda_results\label_2\boxplot_weight.png
#     - weight 箱线图逻辑已保存: eicu_eda_results\insights\label_2_boxplot_insights_weight.txt
#   - 类别特征单变量分析...
#
# 3. Label 3 单变量分析...
#   - 数值特征单变量分析...
#     - age 直方图已保存: eicu_eda_results\label_3\hist_age.png
#     - age 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_age.txt
#     - age 箱线图已保存: eicu_eda_results\label_3\boxplot_age.png
#     - age 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_age.txt
#     - gender_Male 直方图已保存: eicu_eda_results\label_3\hist_gender_Male.png
#     - gender_Male 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_gender_Male.txt
#     - gender_Male 箱线图已保存: eicu_eda_results\label_3\boxplot_gender_Male.png
#     - gender_Male 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_gender_Male.txt
#     - heartrate 直方图已保存: eicu_eda_results\label_3\hist_heartrate.png
#     - heartrate 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_heartrate.txt
#     - heartrate 箱线图已保存: eicu_eda_results\label_3\boxplot_heartrate.png
#     - heartrate 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_heartrate.txt
#     - height 直方图已保存: eicu_eda_results\label_3\hist_height.png
#     - height 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_height.txt
#     - height 箱线图已保存: eicu_eda_results\label_3\boxplot_height.png
#     - height 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_height.txt
#     - ibp_diastolic 直方图已保存: eicu_eda_results\label_3\hist_ibp_diastolic.png
#     - ibp_diastolic 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_ibp_diastolic.txt
#     - ibp_diastolic 箱线图已保存: eicu_eda_results\label_3\boxplot_ibp_diastolic.png
#     - ibp_diastolic 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_ibp_diastolic.txt
#     - ibp_mean 直方图已保存: eicu_eda_results\label_3\hist_ibp_mean.png
#     - ibp_mean 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_ibp_mean.txt
#     - ibp_mean 箱线图已保存: eicu_eda_results\label_3\boxplot_ibp_mean.png
#     - ibp_mean 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_ibp_mean.txt
#     - ibp_systolic 直方图已保存: eicu_eda_results\label_3\hist_ibp_systolic.png
#     - ibp_systolic 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_ibp_systolic.txt
#     - ibp_systolic 箱线图已保存: eicu_eda_results\label_3\boxplot_ibp_systolic.png
#     - ibp_systolic 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_ibp_systolic.txt
#     - labalbumin 直方图已保存: eicu_eda_results\label_3\hist_labalbumin.png
#     - labalbumin 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labalbumin.txt
#     - labalbumin 箱线图已保存: eicu_eda_results\label_3\boxplot_labalbumin.png
#     - labalbumin 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_labalbumin.txt
#     - labalt 直方图已保存: eicu_eda_results\label_3\hist_labalt.png
#     - labalt 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labalt.txt
#     - labalt 箱线图已保存: eicu_eda_results\label_3\boxplot_labalt.png
#     - labalt 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_labalt.txt
#     - labaniongap 直方图已保存: eicu_eda_results\label_3\hist_labaniongap.png
#     - labaniongap 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labaniongap.txt
#     - labaniongap 箱线图已保存: eicu_eda_results\label_3\boxplot_labaniongap.png
#     - labaniongap 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_labaniongap.txt
#     - labast 直方图已保存: eicu_eda_results\label_3\hist_labast.png
#     - labast 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labast.txt
#     - labast 箱线图已保存: eicu_eda_results\label_3\boxplot_labast.png
#     - labast 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_labast.txt
#     - labbedglucose 直方图已保存: eicu_eda_results\label_3\hist_labbedglucose.png
#     - labbedglucose 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labbedglucose.txt
#     - labbedglucose 箱线图已保存: eicu_eda_results\label_3\boxplot_labbedglucose.png
#     - labbedglucose 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_labbedglucose.txt
#     - labbun 直方图已保存: eicu_eda_results\label_3\hist_labbun.png
#     - labbun 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labbun.txt
#     - labbun 箱线图已保存: eicu_eda_results\label_3\boxplot_labbun.png
#     - labbun 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_labbun.txt
#     - labcalcium 直方图已保存: eicu_eda_results\label_3\hist_labcalcium.png
#     - labcalcium 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labcalcium.txt
#     - labcalcium 箱线图已保存: eicu_eda_results\label_3\boxplot_labcalcium.png
#     - labcalcium 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_labcalcium.txt
#     - labchloride 直方图已保存: eicu_eda_results\label_3\hist_labchloride.png
#     - labchloride 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labchloride.txt
#     - labchloride 箱线图已保存: eicu_eda_results\label_3\boxplot_labchloride.png
#     - labchloride 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_labchloride.txt
#     - labcreatinine 直方图已保存: eicu_eda_results\label_3\hist_labcreatinine.png
#     - labcreatinine 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labcreatinine.txt
#     - labcreatinine 箱线图已保存: eicu_eda_results\label_3\boxplot_labcreatinine.png
#     - labcreatinine 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_labcreatinine.txt
#     - labfreecalcium 直方图已保存: eicu_eda_results\label_3\hist_labfreecalcium.png
#     - labfreecalcium 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labfreecalcium.txt
#     - labfreecalcium 箱线图已保存: eicu_eda_results\label_3\boxplot_labfreecalcium.png
#     - labfreecalcium 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_labfreecalcium.txt
#     - labhct 直方图已保存: eicu_eda_results\label_3\hist_labhct.png
#     - labhct 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labhct.txt
#     - labhct 箱线图已保存: eicu_eda_results\label_3\boxplot_labhct.png
#     - labhct 箱线图逻辑已保存: eicu_eda_results\insights\label_3_boxplot_insights_labhct.txt
#     - labhgb 直方图已保存: eicu_eda_results\label_3\hist_labhgb.png
#     - labhgb 直方图逻辑已保存: eicu_eda_results\insights\label_3_hist_insights_labhgb.txt
#     - labhgb 箱线图已保存: eicu_eda_results\label_3\boxplot_labhgb.png
# ...
#     - 类别特征单变量分析...
#       - labtotalco2 直方图已保存: mimic_eda_results\delirium_vs_no_delirium\hist_labtotalco2.png
#       - labtotalco2 直方图逻辑已保存: mimic_eda_results\insights\group_hist_insights_labtotalco2.txt
#       - labtotalco2 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labtotalco2.png
#       - labtotalco2 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labtotalco2.png
#     - 类别特征单变量分析...
#       - labwbc 直方图已保存: mimic_eda_results\delirium_vs_no_delirium\hist_labwbc.png
#       - labwbc 直方图逻辑已保存: mimic_eda_results\insights\group_hist_insights_labwbc.txt
#       - labwbc 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labwbc.png
#       - labwbc 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labwbc.png
#     - 类别特征单变量分析...
#       - nibp_diastolic 直方图已保存: mimic_eda_results\delirium_vs_no_delirium\hist_nibp_diastolic.png
#       - nibp_diastolic 直方图逻辑已保存: mimic_eda_results\insights\group_hist_insights_nibp_diastolic.txt
#       - nibp_diastolic 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_diastolic.png
#       - nibp_diastolic 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_diastolic.png
#     - 类别特征单变量分析...
#       - nibp_mean 直方图已保存: mimic_eda_results\delirium_vs_no_delirium\hist_nibp_mean.png
#       - nibp_mean 直方图逻辑已保存: mimic_eda_results\insights\group_hist_insights_nibp_mean.txt
#       - nibp_mean 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_mean.png
#       - nibp_mean 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_mean.png
#     - 类别特征单变量分析...
#       - nibp_systolic 直方图已保存: mimic_eda_results\delirium_vs_no_delirium\hist_nibp_systolic.png
#       - nibp_systolic 直方图逻辑已保存: mimic_eda_results\insights\group_hist_insights_nibp_systolic.txt
#       - nibp_systolic 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_systolic.png
#       - nibp_systolic 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_systolic.png
#     - 类别特征单变量分析...
#       - respiratoryrate 直方图已保存: mimic_eda_results\delirium_vs_no_delirium\hist_respiratoryrate.png
#       - respiratoryrate 直方图逻辑已保存: mimic_eda_results\insights\group_hist_insights_respiratoryrate.txt
#       - respiratoryrate 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_respiratoryrate.png
#       - respiratoryrate 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_respiratoryrate.png
#     - 类别特征单变量分析...
#       - spo2 直方图已保存: mimic_eda_results\delirium_vs_no_delirium\hist_spo2.png
#       - spo2 直方图逻辑已保存: mimic_eda_results\insights\group_hist_insights_spo2.txt
#       - spo2 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_spo2.png
#       - spo2 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_spo2.png
#     - 类别特征单变量分析...
#       - temperature 直方图已保存: mimic_eda_results\delirium_vs_no_delirium\hist_temperature.png
#       - temperature 直方图逻辑已保存: mimic_eda_results\insights\group_hist_insights_temperature.txt
#       - temperature 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_temperature.png
#       - temperature 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_temperature.png
#     - 类别特征单变量分析...
#       - weight 直方图已保存: mimic_eda_results\delirium_vs_no_delirium\hist_weight.png
#       - weight 直方图逻辑已保存: mimic_eda_results\insights\group_hist_insights_weight.txt
#       - weight 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_weight.png
#       - weight 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_weight.png
#     - 类别特征单变量分析...
#   - 分组数据的双变量分析 (vs. label_group)...
#     - 数值特征 vs. label_group...
#       - age vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_age_vs_group_label.png
#       - age vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_age_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - gender_Male vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_gender_Male_vs_group_label.png
#       - gender_Male vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_gender_Male_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - heartrate vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_heartrate_vs_group_label.png
#       - heartrate vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_heartrate_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - height vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_height_vs_group_label.png
#       - height vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_height_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - ibp_diastolic vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_ibp_diastolic_vs_group_label.png
#       - ibp_diastolic vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_ibp_diastolic_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - ibp_mean vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_ibp_mean_vs_group_label.png
#       - ibp_mean vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_ibp_mean_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - ibp_systolic vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_ibp_systolic_vs_group_label.png
#       - ibp_systolic vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_ibp_systolic_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labalbumin vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labalbumin_vs_group_label.png
#       - labalbumin vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labalbumin_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labalt vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labalt_vs_group_label.png
#       - labalt vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labalt_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labaniongap vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labaniongap_vs_group_label.png
#       - labaniongap vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labaniongap_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labast vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labast_vs_group_label.png
#       - labast vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labast_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labbedglucose vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labbedglucose_vs_group_label.png
#       - labbedglucose vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labbedglucose_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labbun vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labbun_vs_group_label.png
#       - labbun vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labbun_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labcalcium vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labcalcium_vs_group_label.png
#       - labcalcium vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labcalcium_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labchloride vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labchloride_vs_group_label.png
#       - labchloride vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labchloride_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labcreatinine vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labcreatinine_vs_group_label.png
#       - labcreatinine vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labcreatinine_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labfreecalcium vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labfreecalcium_vs_group_label.png
#       - labfreecalcium vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labfreecalcium_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labhct vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labhct_vs_group_label.png
#       - labhct vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labhct_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labhgb vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labhgb_vs_group_label.png
#       - labhgb vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labhgb_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - lablactate vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_lablactate_vs_group_label.png
#       - lablactate vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_lablactate_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - lablymphocytes vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_lablymphocytes_vs_group_label.png
#       - lablymphocytes vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_lablymphocytes_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labneutrophilcount vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labneutrophilcount_vs_group_label.png
#       - labneutrophilcount vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labneutrophilcount_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labpco2 vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labpco2_vs_group_label.png
#       - labpco2 vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labpco2_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labph vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labph_vs_group_label.png
#       - labph vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labph_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labplateletcount vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labplateletcount_vs_group_label.png
#       - labplateletcount vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labplateletcount_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labpo2 vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labpo2_vs_group_label.png
#       - labpo2 vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labpo2_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labpotassium vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labpotassium_vs_group_label.png
#       - labpotassium vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labpotassium_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labpt vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labpt_vs_group_label.png
#       - labpt vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labpt_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labptinr vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labptinr_vs_group_label.png
#       - labptinr vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labptinr_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labptt vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labptt_vs_group_label.png
#       - labptt vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labptt_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labrbc vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labrbc_vs_group_label.png
#       - labrbc vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labrbc_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labrdw vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labrdw_vs_group_label.png
#       - labrdw vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labrdw_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labsodium vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labsodium_vs_group_label.png
#       - labsodium vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labsodium_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labtotalbilirubin vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labtotalbilirubin_vs_group_label.png
#       - labtotalbilirubin vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labtotalbilirubin_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labtotalco2 vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labtotalco2_vs_group_label.png
#       - labtotalco2 vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labtotalco2_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - labwbc vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labwbc_vs_group_label.png
#       - labwbc vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_labwbc_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - nibp_diastolic vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_diastolic_vs_group_label.png
#       - nibp_diastolic vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_diastolic_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - nibp_mean vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_mean_vs_group_label.png
#       - nibp_mean vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_mean_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - nibp_systolic vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_systolic_vs_group_label.png
#       - nibp_systolic vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_nibp_systolic_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - respiratoryrate vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_respiratoryrate_vs_group_label.png
#       - respiratoryrate vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_respiratoryrate_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - spo2 vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_spo2_vs_group_label.png
#       - spo2 vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_spo2_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - temperature vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_temperature_vs_group_label.png
#       - temperature vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_temperature_vs_group_label.png
#     - 类别特征 vs. label_group...
#       - weight vs. label_group 箱线图已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_weight_vs_group_label.png
#       - weight vs. label_group 箱线图逻辑已保存: mimic_eda_results\delirium_vs_no_delirium\boxplot_weight_vs_group_label.png
#     - 类别特征 vs. label_group...
#
# 5. 缺失值分析 (Missing Value Analysis) - 整体数据...
#   - 整体数据缺失值统计已保存到: mimic_eda_results\overall\missing_value_analysis.csv
#   - 整体数据缺失值逻辑已保存到: mimic_eda_results\insights\missing_value_insights.txt
#   - 缺失值可视化 (如果 missingno 已安装)...
#     - 缺失值矩阵可视化已保存: mimic_eda_results\overall\missing_value_matrix.png
#     - 缺失值柱状图可视化已保存: mimic_eda_results\overall\missing_value_bar.png
#
# EDA 分析完成，结果已保存到目录: mimic_eda_results
#   - 图片逻辑文本 insights 已保存到目录: mimic_eda_results\insights
#   - **总的文本逻辑总结已保存到: mimic_eda_results\insights\eda_insights_summary.txt**
